# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Test for is_cold

# %%
x = ['5by5', '100by100', '1000by1000', '5000by5000']
d1 = np.array([0.00027347, 0.00019026, 0.00045323, 0.00024104, 0.00034952, 0.00014496,
 0.00024509, 0.00024104, 0.00014806, 0.00016904])
d2 = np.array([0.00028396, 0.00029039, 0.00025558, 0.00021768, 0.00016022, 0.00027013,
 0.00026512, 0.00028896, 0.00016618, 0.00016046])
d3 = np.array([0.00164247, 0.00198817, 0.00055981, 0.00056314, 0.00102258, 0.00099373,
 0.00072217, 0.00064683, 0.00088859, 0.00059104])
d4 = np.array([0.43961716, 0.34502935, 0.34146333, 0.30820966, 0.1491425,  0.15040112,
 0.15313935, 0.15295529, 0.15003181, 0.15261817])
p1 = np.array([0.0030489,  0.00066233, 0.00073314, 0.00194263, 0.00320244, 0.00060153,
 0.00058341, 0.00053239, 0.00058603, 0.00069141])
p2 = np.array([0.00194931, 0.00239229, 0.00074077, 0.00109601, 0.00060797, 0.00088644,
 0.00071239, 0.00108719, 0.00085425, 0.00053072])
p3 = np.array([0.0056901,  0.00380635, 0.00298929, 0.00390196, 0.00221372, 0.00404906,
 0.00430417, 0.00237966, 0.00574064, 0.00297403])
p4 = np.array([0.52158475, 0.52915239, 0.37925363, 0.46712685, 0.37836719, 0.3767314,
 0.41324472, 0.44056654, 0.3861537,  0.37707877])
a1 = np.array([0.00363874, 0.00228119, 0.00443912, 0.01109314, 0.01007032, 0.00474095,
 0.00068045, 0.00795245, 0.01047993, 0.00062251])
a2 = np.array([0.00477338, 0.00312281, 0.00094438, 0.00676417, 0.00893974, 0.00867081,
 0.00596166, 0.0049367,  0.00527811, 0.00088024])
a3 = np.array([0.01150775, 0.03353691, 0.01313901, 0.00417185, 0.01097751, 0.00433755,
 0.00440526, 0.0109365,  0.02110553, 0.00872397])
a4 = np.array([5.04050612, 5.16968322, 6.08748841, 5.27268767, 5.47605324, 5.18512797,
 5.23438311, 4.87368178, 4.45746517, 6.61400533])

# %%
plt.figure(figsize=(4, 3))
plt.scatter(['direct']*10,d1)
plt.scatter(['redis']*10,p1)
plt.scatter(['anna']*10,a1)
plt.title('5by5 matrix')
#plt.show()
plt.savefig('5by5')

# %%
plt.figure(figsize=(4, 3))
plt.scatter(['direct']*10,d2)
plt.scatter(['redis']*10,p2)
plt.scatter(['anna']*10,a2)
plt.title('100by100 matrix')
#plt.show()
plt.savefig('100by100')

# %%
plt.figure(figsize=(4, 3))
plt.scatter(['direct']*10,d3)
plt.scatter(['redis']*10,p3)
plt.scatter(['anna']*10,a3)
plt.title('1000by1000 matrix')
#plt.show()
plt.savefig('1000by1000')

# %%
plt.figure(figsize=(4, 3))
plt.scatter(['direct']*10,d4)
plt.scatter(['redis']*10,p4)
plt.scatter(['anna']*10,a4)
plt.title('5000by5000 matrix')
#plt.show()
plt.savefig('5000by5000')

# %% [markdown]
# ### Test for
